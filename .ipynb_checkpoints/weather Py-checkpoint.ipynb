# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from citipy import citipy
from datetime import datetime
from random import uniform
from config import api_key

# %%
# Create a df to lat, lon 
column_names = ["City", "Country"]
cities_df = pd.DataFrame(columns=column_names)

# %%
# Randomly generate a list of 1750 cities. Use 50 to test for duplicates.
for x in range(1750):
    lat, lng = np.random.uniform(low=-90.000, high=90.000), np.random.uniform(low=-180.000, high=180.000)
    city = citipy.nearest_city(lat, lng)
    cities_df = cities_df.append({"City": city.city_name,"Country": city.country_code,}, ignore_index=True)

#Remove duplicate cities
cities_df = cities_df.drop_duplicates(subset='City').reset_index()
cities_df.count()
# Out:
# index      709
# City       709
# Country    709
# dtype: int64

# %%
#Create a df to add all the data from the API calls.
column_names = ["City", "Country","Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]
clean_cities_df = pd.DataFrame(columns=column_names)

# Loop through the list of cities and add the data to the df.
url = "http://api.openweathermap.org/data/2.5/weather?"

row_count = 1

print("Beginning Data Retrieval")
for index, row in cities_df.iterrows():
    target_city = row["City"]
    target_url = url + "appid=" + api_key + "&units=IMPERIAL" + "&q=" + target_city.replace(" ","+")
    city_data = requests.get(target_url).json()
    if city_data["cod"] == "404":
        print("City not found, skipping...")
        
    else:
        
            clean_cities_df.set_value(index, "City", city_data["name"])
            clean_cities_df.set_value(index, "Country", city_data["sys"]["country"])
            clean_cities_df.set_value(index, "Temperature (F)", city_data["main"]["temp"])
            clean_cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
            clean_cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
            clean_cities_df.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
            clean_cities_df.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
            clean_cities_df.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        
            print("------------------------")
            print("Proceesing: City # " , row_count, ' | ' , city_data["name"], city_data["sys"]["country"])
            print(target_url)
            row_count += 1
        
        
clean_cities_df.count()
# Out:
# Beginning Data Retrieval
# ------------------------
# Proceesing: City #  1  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=hermanus
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ------------------------
# Proceesing: City #  2  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: City #  3  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  4  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  5  |  Devils Lake US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=devils+lake
# ------------------------
# Proceesing: City #  6  |  Tecoanapa MX
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tecoanapa
# ------------------------
# Proceesing: City #  7  |  Tilichiki RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tilichiki
# ------------------------
# Proceesing: City #  8  |  Luderitz NA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=luderitz
# ------------------------
# Proceesing: City #  9  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  10  |  Mahebourg MU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mahebourg
# ------------------------
# Proceesing: City #  11  |  Kaitangata NZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kaitangata
# ------------------------
# Proceesing: City #  12  |  Oranjemund ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=oranjemund
# ------------------------
# Proceesing: City #  13  |  Huarmey PE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=huarmey
# ------------------------
# Proceesing: City #  14  |  Mayo CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mayo
# ------------------------
# Proceesing: City #  15  |  Cabo San Lucas MX
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=cabo+san+lucas
# City not found, skipping...
# ------------------------
# Proceesing: City #  16  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  17  |  Necochea AR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=necochea
# City not found, skipping...
# ------------------------
# Proceesing: City #  18  |  Chumikan RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=chumikan
# ------------------------
# Proceesing: City #  19  |  Torbay CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=torbay
# ------------------------
# Proceesing: City #  20  |  Arlit NE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=arlit
# ------------------------
# Proceesing: City #  21  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: City #  22  |  Half Moon Bay US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=half+moon+bay
# ------------------------
# Proceesing: City #  23  |  Sur OM
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sur
# ------------------------
# Proceesing: City #  24  |  Folsom US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=folsom
# ------------------------
# Proceesing: City #  25  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=yellowknife
# ------------------------
# Proceesing: City #  26  |  Ambilobe MG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ambilobe
# ------------------------
# Proceesing: City #  27  |  Yeniseysk RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=yeniseysk
# ------------------------
# Proceesing: City #  28  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: City #  29  |  Codrington AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=codrington
# ------------------------
# Proceesing: City #  30  |  Geraldton CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=geraldton
# ------------------------
# Proceesing: City #  31  |  Tomatlan MX
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tomatlan
# ------------------------
# Proceesing: City #  32  |  Kieta PG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kieta
# ------------------------
# Proceesing: City #  33  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=lebu
# ------------------------
# Proceesing: City #  34  |  Cherskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=cherskiy
# City not found, skipping...
# ------------------------
# Proceesing: City #  35  |  Mar del Plata AR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mar+del+plata
# ------------------------
# Proceesing: City #  36  |  Bridlington GB
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bridlington
# ------------------------
# Proceesing: City #  37  |  Carutapera BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=carutapera
# ------------------------
# Proceesing: City #  38  |  Vaitape PF
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=vaitape
# ------------------------
# Proceesing: City #  39  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  40  |  Sao Gabriel BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sao+gabriel
# ------------------------
# Proceesing: City #  41  |  Aitape PG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=aitape
# ------------------------
# Proceesing: City #  42  |  Saint-Georges CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=saint-georges
# City not found, skipping...
# ------------------------
# Proceesing: City #  43  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  44  |  Vila Velha BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=vila+velha
# ------------------------
# Proceesing: City #  45  |  Tezu IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tezu
# ------------------------
# Proceesing: City #  46  |  Tazovskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tazovskiy
# ------------------------
# Proceesing: City #  47  |  The Valley AI
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=the+valley
# ------------------------
# Proceesing: City #  48  |  Leshukonskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=leshukonskoye
# ------------------------
# Proceesing: City #  49  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ribeira+grande
# ------------------------
# Proceesing: City #  50  |  Sabang PH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sabang
# ------------------------
# Proceesing: City #  51  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: City #  52  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=khatanga
# ------------------------
# Proceesing: City #  53  |  Muroto JP
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=muroto
# ------------------------
# Proceesing: City #  54  |  Saint-Francois FR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=saint-francois
# ------------------------
# Proceesing: City #  55  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  56  |  Ostrovnoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ostrovnoy
# ------------------------
# Proceesing: City #  57  |  Belaya Gora RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=belaya+gora
# City not found, skipping...
# ------------------------
# Proceesing: City #  58  |  Sinnamary GF
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sinnamary
# ------------------------
# Proceesing: City #  59  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  60  |  Monte Aprazivel BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=monte+aprazivel
# ------------------------
# Proceesing: City #  61  |  Chipinge ZW
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=chipinge
# ------------------------
# Proceesing: City #  62  |  Tucuman PE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tucuman
# ------------------------
# Proceesing: City #  63  |  Touros BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=touros
# ------------------------
# Proceesing: City #  64  |  Faanui PF
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=faanui
# ------------------------
# Proceesing: City #  65  |  Navrongo GH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=navrongo
# City not found, skipping...
# ------------------------
# Proceesing: City #  66  |  Tiksi RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tiksi
# City not found, skipping...
# ------------------------
# Proceesing: City #  67  |  Ayagoz KZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ayagoz
# ------------------------
# Proceesing: City #  68  |  Sergeyevka KZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sergeyevka
# ------------------------
# Proceesing: City #  69  |  Carnarvon ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=carnarvon
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  70  |  Severo-Kurilsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=severo-kurilsk
# ------------------------
# Proceesing: City #  71  |  Bubaque GW
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bubaque
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  72  |  Kahului US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kahului
# ------------------------
# Proceesing: City #  73  |  La Crosse US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=la+crosse
# ------------------------
# Proceesing: City #  74  |  Bethel US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bethel
# ------------------------
# Proceesing: City #  75  |  Kasongo-Lunda CD
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kasongo-lunda
# ------------------------
# Proceesing: City #  76  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kodiak
# ------------------------
# Proceesing: City #  77  |  Champerico MX
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=champerico
# ------------------------
# Proceesing: City #  78  |  Cockburn Town TC
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=cockburn+town
# ------------------------
# Proceesing: City #  79  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=hilo
# ------------------------
# Proceesing: City #  80  |  Araguaina BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=araguaina
# ------------------------
# Proceesing: City #  81  |  Neiafu TO
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=neiafu
# ------------------------
# Proceesing: City #  82  |  Sitka US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sitka
# ------------------------
# Proceesing: City #  83  |  Kenai US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kenai
# ------------------------
# Proceesing: City #  84  |  Kungurtug RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kungurtug
# ------------------------
# Proceesing: City #  85  |  Guerrero Negro MX
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=guerrero+negro
# ------------------------
# Proceesing: City #  86  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=avarua
# ------------------------
# Proceesing: City #  87  |  Naspur IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=naspur
# ------------------------
# Proceesing: City #  88  |  Clyde River CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=clyde+river
# ------------------------
# Proceesing: City #  89  |  Bajram Curri AL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bajram+curri
# ------------------------
# Proceesing: City #  90  |  Mookane BW
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mookane
# ------------------------
# Proceesing: City #  91  |  Tokur RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tokur
# ------------------------
# Proceesing: City #  92  |  Ancud CL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ancud
# ------------------------
# Proceesing: City #  93  |  Itarema BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=itarema
# ------------------------
# Proceesing: City #  94  |  Port Elizabeth US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=port+elizabeth
# City not found, skipping...
# ------------------------
# Proceesing: City #  95  |  Fairbanks US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=fairbanks
# ------------------------
# Proceesing: City #  96  |  Kamennomostskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kamennomostskiy
# ------------------------
# Proceesing: City #  97  |  Saint-Augustin FR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=saint-augustin
# City not found, skipping...
# ------------------------
# Proceesing: City #  98  |  Maceio BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=maceio
# ------------------------
# Proceesing: City #  99  |  Pisco PE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=pisco
# ------------------------
# Proceesing: City #  100  |  Benjamin Aceval PY
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=benjamin+aceval
# ------------------------
# Proceesing: City #  101  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=new+norfolk
# ------------------------
# Proceesing: City #  102  |  Kholodnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kholodnyy
# ------------------------
# Proceesing: City #  103  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=butaritari
# ------------------------
# Proceesing: City #  104  |  Merritt Island US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=merritt+island
# ------------------------
# Proceesing: City #  105  |  Oktyabrskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=oktyabrskoye
# ------------------------
# Proceesing: City #  106  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=atuona
# ------------------------
# Proceesing: City #  107  |  Axim GH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=axim
# ------------------------
# Proceesing: City #  108  |  Tabuk PH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tabuk
# ------------------------
# Proceesing: City #  109  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=saint-philippe
# ------------------------
# Proceesing: City #  110  |  Uvira CD
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=uvira
# ------------------------
# Proceesing: City #  111  |  Cidreira BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=cidreira
# ------------------------
# Proceesing: City #  112  |  Te Anau NZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=te+anau
# ------------------------
# Proceesing: City #  113  |  Deer Lake CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=deer+lake
# ------------------------
# Proceesing: City #  114  |  Port Alfred ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=port+alfred
# ------------------------
# Proceesing: City #  115  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  116  |  Sorong ID
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sorong
# ------------------------
# Proceesing: City #  117  |  Coquimbo CL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=coquimbo
# ------------------------
# Proceesing: City #  118  |  Nokaneng BW
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=nokaneng
# ------------------------
# Proceesing: City #  119  |  Saint-Pierre FR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=saint-pierre
# ------------------------
# Proceesing: City #  120  |  Bathsheba BB
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bathsheba
# ------------------------
# Proceesing: City #  121  |  San Rafael AR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=san+rafael
# ------------------------
# Proceesing: City #  122  |  Ukiah US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ukiah
# ------------------------
# Proceesing: City #  123  |  Taoudenni ML
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=taoudenni
# ------------------------
# Proceesing: City #  124  |  Narsaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=narsaq
# ------------------------
# Proceesing: City #  125  |  Palmer US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=palmer
# ------------------------
# Proceesing: City #  126  |  Castro CL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=castro
# ------------------------
# Proceesing: City #  127  |  Chimbote PE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=chimbote
# ------------------------
# Proceesing: City #  128  |  Melbu NO
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=melbu
# ------------------------
# Proceesing: City #  129  |  Altamira BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=altamira
# ------------------------
# Proceesing: City #  130  |  Sakaiminato JP
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sakaiminato
# ------------------------
# Proceesing: City #  131  |  Tuktoyaktuk CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tuktoyaktuk
# ------------------------
# Proceesing: City #  132  |  Manggar ID
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=manggar
# ------------------------
# Proceesing: City #  133  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=victoria
# ------------------------
# Proceesing: City #  134  |  Brookhaven US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=brookhaven
# ------------------------
# Proceesing: City #  135  |  Gweru ZW
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=gweru
# ------------------------
# Proceesing: City #  136  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: City #  137  |  Dickinson US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=dickinson
# ------------------------
# Proceesing: City #  138  |  Huangnihe CN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=huangnihe
# ------------------------
# Proceesing: City #  139  |  Severo-Yeniseyskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=severo-yeniseyskiy
# ------------------------
# Proceesing: City #  140  |  Panama City US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=panama+city
# ------------------------
# Proceesing: City #  141  |  Glencoe ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=glencoe
# ------------------------
# Proceesing: City #  142  |  Saint George GR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=saint+george
# ------------------------
# Proceesing: City #  143  |  Beloha MG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=beloha
# ------------------------
# Proceesing: City #  144  |  Vershino-Darasunskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=vershino-darasunskiy
# ------------------------
# Proceesing: City #  145  |  Upernavik GL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=upernavik
# ------------------------
# Proceesing: City #  146  |  Verkhnyaya Inta RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=verkhnyaya+inta
# ------------------------
# Proceesing: City #  147  |  Pacific Grove US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=pacific+grove
# ------------------------
# Proceesing: City #  148  |  Stonewall CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=stonewall
# ------------------------
# Proceesing: City #  149  |  Afzalpur IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=afzalpur
# ------------------------
# Proceesing: City #  150  |  Misratah LY
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=misratah
# ------------------------
# Proceesing: City #  151  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=saskylakh
# ------------------------
# Proceesing: City #  152  |  San Jose PH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=san+jose
# ------------------------
# Proceesing: City #  153  |  Port Shepstone ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=port+shepstone
# ------------------------
# Proceesing: City #  154  |  Plouzane FR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=plouzane
# ------------------------
# Proceesing: City #  155  |  Sept-Iles CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sept-iles
# ------------------------
# Proceesing: City #  156  |  Tabontabon PH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tabontabon
# ------------------------
# Proceesing: City #  157  |  Trat TH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=trat
# City not found, skipping...
# ------------------------
# Proceesing: City #  158  |  Aklavik CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=aklavik
# ------------------------
# Proceesing: City #  159  |  Grand Gaube MU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=grand+gaube
# City not found, skipping...
# ------------------------
# Proceesing: City #  160  |  Krasne UA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=krasne
# ------------------------
# Proceesing: City #  161  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  162  |  Sao Joao da Barra BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sao+joao+da+barra
# ------------------------
# Proceesing: City #  163  |  Mount Gambier AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mount+gambier
# ------------------------
# Proceesing: City #  164  |  Atbasar KZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=atbasar
# City not found, skipping...
# ------------------------
# Proceesing: City #  165  |  Caxito BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=caxito
# ------------------------
# Proceesing: City #  166  |  Tchollire CM
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tchollire
# ------------------------
# Proceesing: City #  167  |  Chokurdakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=chokurdakh
# ------------------------
# Proceesing: City #  168  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=barrow
# ------------------------
# Proceesing: City #  169  |  Pandan PH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=pandan
# ------------------------
# Proceesing: City #  170  |  Mallaig GB
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mallaig
# ------------------------
# Proceesing: City #  171  |  Ayorou NE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ayorou
# ------------------------
# Proceesing: City #  172  |  Flin Flon CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=flin+flon
# ------------------------
# Proceesing: City #  173  |  Edd ER
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=edd
# ------------------------
# Proceesing: City #  174  |  Provideniya RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=provideniya
# ------------------------
# Proceesing: City #  175  |  East London ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=east+london
# ------------------------
# Proceesing: City #  176  |  Sri Aman MY
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sri+aman
# ------------------------
# Proceesing: City #  177  |  Calabozo VE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=calabozo
# City not found, skipping...
# ------------------------
# Proceesing: City #  178  |  Vilhena BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=vilhena
# ------------------------
# Proceesing: City #  179  |  Alice Town BS
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=alice+town
# ------------------------
# Proceesing: City #  180  |  Namibe AO
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=namibe
# ------------------------
# Proceesing: City #  181  |  Luanda AO
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=luanda
# ------------------------
# Proceesing: City #  182  |  Bafoulabe ML
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bafoulabe
# ------------------------
# Proceesing: City #  183  |  Pevek RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=pevek
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  184  |  Hecun CN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=hecun
# ------------------------
# Proceesing: City #  185  |  Lethem GY
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=lethem
# ------------------------
# Proceesing: City #  186  |  Tasiilaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tasiilaq
# ------------------------
# Proceesing: City #  187  |  Havre US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=havre
# ------------------------
# Proceesing: City #  188  |  Zakamensk RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=zakamensk
# ------------------------
# Proceesing: City #  189  |  Gillette US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=gillette
# ------------------------
# Proceesing: City #  190  |  Iaciara BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=iaciara
# ------------------------
# Proceesing: City #  191  |  Ylojarvi FI
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ylojarvi
# ------------------------
# Proceesing: City #  192  |  Kavaratti IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kavaratti
# ------------------------
# Proceesing: City #  193  |  Sajokaza HU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sajokaza
# ------------------------
# Proceesing: City #  194  |  Ambovombe MG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ambovombe
# ------------------------
# Proceesing: City #  195  |  Tutin RS
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tutin
# ------------------------
# Proceesing: City #  196  |  Ixtapa MX
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ixtapa
# ------------------------
# Proceesing: City #  197  |  Ahipara NZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ahipara
# ------------------------
# Proceesing: City #  198  |  San Patricio PY
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=san+patricio
# ------------------------
# Proceesing: City #  199  |  Kuytun RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kuytun
# ------------------------
# Proceesing: City #  200  |  College US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=college
# ------------------------
# Proceesing: City #  201  |  Dali CN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=dali
# ------------------------
# Proceesing: City #  202  |  Zhuhai CN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=zhuhai
# ------------------------
# Proceesing: City #  203  |  San Isidro PH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=san+isidro
# ------------------------
# Proceesing: City #  204  |  Bilma NE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bilma
# ------------------------
# Proceesing: City #  205  |  Sabratah LY
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sabratah
# ------------------------
# Proceesing: City #  206  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: City #  207  |  Zyryanskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=zyryanskoye
# ------------------------
# Proceesing: City #  208  |  Nikolskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=nikolskoye
# ------------------------
# Proceesing: City #  209  |  Dubai AE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=dubai
# ------------------------
# Proceesing: City #  210  |  Micheweni TZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=micheweni
# ------------------------
# Proceesing: City #  211  |  Nortelandia BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=nortelandia
# ------------------------
# Proceesing: City #  212  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=dikson
# ------------------------
# Proceesing: City #  213  |  Lubao PH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=lubao
# ------------------------
# Proceesing: City #  214  |  Vangaindrano MG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=vangaindrano
# ------------------------
# Proceesing: City #  215  |  Portland US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=portland
# ------------------------
# Proceesing: City #  216  |  Fortuna ES
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=fortuna
# City not found, skipping...
# ------------------------
# Proceesing: City #  217  |  Port Moresby PG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=port+moresby
# ------------------------
# Proceesing: City #  218  |  Vao EE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=vao
# ------------------------
# Proceesing: City #  219  |  Lagos NG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=lagos
# ------------------------
# Proceesing: City #  220  |  Clyde NZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=clyde
# ------------------------
# Proceesing: City #  221  |  Nyurba RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=nyurba
# ------------------------
# Proceesing: City #  222  |  Kununurra AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kununurra
# ------------------------
# Proceesing: City #  223  |  Atar MR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=atar
# ------------------------
# Proceesing: City #  224  |  Mutsu JP
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mutsu
# ------------------------
# Proceesing: City #  225  |  Iskateley RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=iskateley
# ------------------------
# Proceesing: City #  226  |  Delhi IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=delhi
# ------------------------
# Proceesing: City #  227  |  Katsuura JP
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=katsuura
# City not found, skipping...
# ------------------------
# Proceesing: City #  228  |  Norman Wells CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=norman+wells
# City not found, skipping...
# ------------------------
# Proceesing: City #  229  |  De Aar ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=de+aar
# ------------------------
# Proceesing: City #  230  |  Poli CM
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=poli
# ------------------------
# Proceesing: City #  231  |  Kudahuvadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kudahuvadhoo
# ------------------------
# Proceesing: City #  232  |  Klaksvik FO
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=klaksvik
# ------------------------
# Proceesing: City #  233  |  Moba CD
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=moba
# ------------------------
# Proceesing: City #  234  |  Kronach DE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kronach
# ------------------------
# Proceesing: City #  235  |  Ciudad Bolivar VE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ciudad+bolivar
# ------------------------
# Proceesing: City #  236  |  Labuhan ID
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=labuhan
# ------------------------
# Proceesing: City #  237  |  Souillac FR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=souillac
# ------------------------
# Proceesing: City #  238  |  Cam Ranh VN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=cam+ranh
# ------------------------
# Proceesing: City #  239  |  Nakapiripirit UG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=nakapiripirit
# ------------------------
# Proceesing: City #  240  |  Voh NC
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=voh
# ------------------------
# Proceesing: City #  241  |  Iwaki JP
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=iwaki
# ------------------------
# Proceesing: City #  242  |  Tuatapere NZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tuatapere
# ------------------------
# Proceesing: City #  243  |  Hasaki JP
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=hasaki
# ------------------------
# Proceesing: City #  244  |  San Carlos de Bariloche AR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=san+carlos+de+bariloche
# ------------------------
# Proceesing: City #  245  |  Changji CN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=changji
# ------------------------
# Proceesing: City #  246  |  Hithadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=hithadhoo
# City not found, skipping...
# ------------------------
# Proceesing: City #  247  |  Arrifes PT
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=arrifes
# ------------------------
# Proceesing: City #  248  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=chuy
# ------------------------
# Proceesing: City #  249  |  Lavrentiya RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=lavrentiya
# ------------------------
# Proceesing: City #  250  |  Ponta do Sol BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ponta+do+sol
# ------------------------
# Proceesing: City #  251  |  Novoagansk RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=novoagansk
# ------------------------
# Proceesing: City #  252  |  Novyy Urengoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=novyy+urengoy
# ------------------------
# Proceesing: City #  253  |  Aykhal RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=aykhal
# ------------------------
# Proceesing: City #  254  |  Namatanai PG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=namatanai
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  255  |  Kimbe PG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kimbe
# ------------------------
# Proceesing: City #  256  |  Shimoda JP
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=shimoda
# ------------------------
# Proceesing: City #  257  |  Naze NG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=naze
# ------------------------
# Proceesing: City #  258  |  Damaturu NG
# ...
# ------------------------
# Proceesing: City #  555  |  Tumaco CO
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tumaco
# ------------------------
# Proceesing: City #  556  |  Red Bluff US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=red+bluff
# City not found, skipping...
# ------------------------
# Proceesing: City #  557  |  Brownsville US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=brownsville
# ------------------------
# Proceesing: City #  558  |  Graaff-Reinet ZA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=graaff-reinet
# ------------------------
# Proceesing: City #  559  |  Gat SN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=gat
# ------------------------
# Proceesing: City #  560  |  Waipawa NZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=waipawa
# ------------------------
# Proceesing: City #  561  |  Sinop TR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sinop
# ------------------------
# Proceesing: City #  562  |  Myaundzha RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=myaundzha
# City not found, skipping...
# ------------------------
# Proceesing: City #  563  |  Itaituba BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=itaituba
# ------------------------
# Proceesing: City #  564  |  Batemans Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=batemans+bay
# ------------------------
# Proceesing: City #  565  |  Madikeri IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=madikeri
# ------------------------
# Proceesing: City #  566  |  Marzuq YE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=marzuq
# ------------------------
# Proceesing: City #  567  |  Bayeux FR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bayeux
# ------------------------
# Proceesing: City #  568  |  Nuoro IT
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=nuoro
# ------------------------
# Proceesing: City #  569  |  Alice Springs AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=alice+springs
# ------------------------
# Proceesing: City #  570  |  Oriximina BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=oriximina
# ------------------------
# Proceesing: City #  571  |  Grindavik IS
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=grindavik
# ------------------------
# Proceesing: City #  572  |  Chachapoyas PE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=chachapoyas
# ------------------------
# Proceesing: City #  573  |  Wajima JP
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=wajima
# ------------------------
# Proceesing: City #  574  |  Los Llanos de Aridane ES
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=los+llanos+de+aridane
# ------------------------
# Proceesing: City #  575  |  Togur RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=togur
# ------------------------
# Proceesing: City #  576  |  Muros ES
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=muros
# ------------------------
# Proceesing: City #  577  |  Buriti dos Lopes BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=buriti+dos+lopes
# ------------------------
# Proceesing: City #  578  |  South River CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=south+river
# City not found, skipping...
# ------------------------
# Proceesing: City #  579  |  Gladstone AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=gladstone
# ------------------------
# Proceesing: City #  580  |  Raudeberg NO
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=raudeberg
# ------------------------
# Proceesing: City #  581  |  Great Yarmouth GB
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=great+yarmouth
# ------------------------
# Proceesing: City #  582  |  Barcelona ES
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=barcelona
# ------------------------
# Proceesing: City #  583  |  Tabory PL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tabory
# ------------------------
# Proceesing: City #  584  |  Marovoay MG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=marovoay
# City not found, skipping...
# ------------------------
# Proceesing: City #  585  |  Shihezi CN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=shihezi
# ------------------------
# Proceesing: City #  586  |  Poopo BO
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=poopo
# ------------------------
# Proceesing: City #  587  |  Samarai PG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=samarai
# ------------------------
# Proceesing: City #  588  |  Kulhudhuffushi MV
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kulhudhuffushi
# ------------------------
# Proceesing: City #  589  |  Mago RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mago
# ------------------------
# Proceesing: City #  590  |  Nouadhibou MR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=nouadhibou
# ------------------------
# Proceesing: City #  591  |  Port-Gentil GA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=port-gentil
# ------------------------
# Proceesing: City #  592  |  Shitkino RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=shitkino
# City not found, skipping...
# ------------------------
# Proceesing: City #  593  |  Yuanping CN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=yuanping
# ------------------------
# Proceesing: City #  594  |  ChengDe CN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=chengde
# ------------------------
# Proceesing: City #  595  |  Antofagasta CL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=antofagasta
# ------------------------
# Proceesing: City #  596  |  Sarangpur IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sarangpur
# ------------------------
# Proceesing: City #  597  |  Yumen CN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=yumen
# ------------------------
# Proceesing: City #  598  |  Mazatlan MX
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mazatlan
# ------------------------
# Proceesing: City #  599  |  Haines Junction CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=haines+junction
# ------------------------
# Proceesing: City #  600  |  Isangel VU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=isangel
# ------------------------
# Proceesing: City #  601  |  Ambulu ID
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ambulu
# ------------------------
# Proceesing: City #  602  |  Eganville CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=eganville
# ------------------------
# Proceesing: City #  603  |  Altinopolis BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=altinopolis
# ------------------------
# Proceesing: City #  604  |  Mokhsogollokh RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mokhsogollokh
# ------------------------
# Proceesing: City #  605  |  Port Macquarie AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=port+macquarie
# ------------------------
# Proceesing: City #  606  |  Sao Jose da Coroa Grande BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sao+jose+da+coroa+grande
# City not found, skipping...
# ------------------------
# Proceesing: City #  607  |  Adrar DZ
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=adrar
# ------------------------
# Proceesing: City #  608  |  Mercedes UY
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mercedes
# ------------------------
# Proceesing: City #  609  |  Tecolutla MX
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=tecolutla
# ------------------------
# Proceesing: City #  610  |  Barra do Corda BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=barra+do+corda
# ------------------------
# Proceesing: City #  611  |  Bongor TD
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bongor
# City not found, skipping...
# ------------------------
# Proceesing: City #  612  |  Jasper US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=jasper
# ------------------------
# Proceesing: City #  613  |  Nuuk GL
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=nuuk
# ------------------------
# Proceesing: City #  614  |  Chebenki RU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=chebenki
# ------------------------
# Proceesing: City #  615  |  Najran SA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=najran
# ------------------------
# Proceesing: City #  616  |  Port Blair IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=port+blair
# ------------------------
# Proceesing: City #  617  |  Chifeng CN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=chifeng
# ------------------------
# Proceesing: City #  618  |  Margate AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=margate
# ------------------------
# Proceesing: City #  619  |  Lerwick GB
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=lerwick
# ------------------------
# Proceesing: City #  620  |  Kirakira SB
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kirakira
# City not found, skipping...
# ------------------------
# Proceesing: City #  621  |  Sola NO
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=sola
# ------------------------
# Proceesing: City #  622  |  Shafter US
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=shafter
# ------------------------
# Proceesing: City #  623  |  Eenhana NA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=eenhana
# ------------------------
# Proceesing: City #  624  |  Agadir MA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=agadir
# ------------------------
# Proceesing: City #  625  |  Lorengau PG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=lorengau
# ------------------------
# Proceesing: City #  626  |  Ucluelet CA
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ucluelet
# ------------------------
# Proceesing: City #  627  |  Kovur IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=kovur
# ------------------------
# Proceesing: City #  628  |  Bonfim BR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bonfim
# ------------------------
# Proceesing: City #  629  |  Byron Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=byron+bay
# ------------------------
# Proceesing: City #  630  |  Road Town VG
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=road+town
# ------------------------
# Proceesing: City #  631  |  Soimi RO
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=soimi
# City not found, skipping...
# ------------------------
# Proceesing: City #  632  |  Dwarka IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=dwarka
# ------------------------
# Proceesing: City #  633  |  Wundanyi KE
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=wundanyi
# ------------------------
# Proceesing: City #  634  |  Ujfeherto HU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=ujfeherto
# ------------------------
# Proceesing: City #  635  |  Rawson AR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=rawson
# ------------------------
# Proceesing: City #  636  |  Yajalon MX
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=yajalon
# ------------------------
# Proceesing: City #  637  |  Carmen PH
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=carmen
# ------------------------
# Proceesing: City #  638  |  Quang Ngai VN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=quang+ngai
# ------------------------
# Proceesing: City #  639  |  Bayir TR
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=bayir
# ------------------------
# Proceesing: City #  640  |  Pemberton AU
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=pemberton
# ------------------------
# Proceesing: City #  641  |  Mangaldai IN
# http://api.openweathermap.org/data/2.5/weather?appid=9c249d808ef6dcb9e1bd1f3a56cae16d&units=IMPERIAL&q=mangaldai
# City                641
# Country             641
# Temperature (F)     641
# Latitude            641
# Longitude           641
# Humidity (%)        641
# Cloudiness (%)      641
# Wind Speed (mph)    641
# dtype: int64

# %%
#Reset the index
clean_cities_df = clean_cities_df.reset_index()
del clean_cities_df['index']
clean_cities_df.head()
# Out:
#           City Country Temperature (F) Latitude Longitude Humidity (%)  \
# 0     Hermanus      ZA            47.7   -34.42     19.24           68
# 1        Bluff      AU           51.75   -23.58    149.07           53
# 2      Rikitea      PF           73.98   -23.12   -134.97          100
# 3       Albany      US            74.1    42.65    -73.75           36
# 4  Devils Lake      US           86.79    48.11    -98.87           70
#
#   Cloudiness (%) Wind Speed (mph)
# 0              0             2.59
# 1              0            13.67
# 2              0             9.98
# 3             20             3.38
# 4             20            18.34

# %%
# Save data to a CSV file
#clean_cities_df.to_csv("/City_Data.csv")

# %%
#Build a scatter plot for Latitude vs. Temperature

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Temperature (F)"], c=clean_cities_df["Temperature (F)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Max Temperature {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-60, 120])

# Save the figure
#plt.savefig("WeatherPy_analysis/Latitude_Temperature.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Humidity (%)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Humidity (%)"], c=clean_cities_df["Humidity (%)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='GnBu', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Humidity (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])

# Save the figure
#plt.savefig("WeatherPy_analysis/Latitude_Humidity.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Cloudiness (%)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Cloudiness (%)"], c=clean_cities_df["Cloudiness (%)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='bone_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Cloudiness (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 125])

# Save the figure
#plt.savefig("WeatherPy_analysis/Latitude_Cloudiness.png")

# Show plot
#plt.show()
# Out:
# (-10, 125)

# %%
#Build a scatter plot for Latitude vs. Wind Speed (mph)

plt.scatter(clean_cities_df["Latitude"], 
            clean_cities_df["Wind Speed (mph)"], c=clean_cities_df["Wind Speed (mph)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='Spectral_r', alpha=0.8, label="City")

# Incorporate the other graph properties
plt.style.use('seaborn')
plt.title(f"City Latitude vs. Wind Speed (mph) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 50])

# Save the figure
#plt.savefig("WeatherPy_analysis/Latitude_WindSpeed.png")

# Show plot
# Out:
# (-10, 50)
